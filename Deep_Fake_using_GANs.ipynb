# %% [markdown]
# <a href="https://colab.research.google.com/github/PRIYESH740/Data-Analysis-on-Olympics-Dataset/blob/main/Deep_Fake_using_GANs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
xiaoxxiao_damedane_vox_data_path = kagglehub.dataset_download('xiaoxxiao/damedane-vox-data')
priyeshmishra81_deep_fake_data_path = kagglehub.dataset_download('priyeshmishra81/deep-fake-data')

print('Data source import complete.')

# %% [markdown]
# #Importing the libraries

# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML

# %% [markdown]
# #Importing the datasets

# %%
source_image=imageio.imread("/kaggle/input/deep-fake-data/RDJ.jpg")
driver_video=imageio.get_reader("/kaggle/input/deep-fake-data/new south Vijay Altitude movie dialogue status KGF 2.mp4")
# Out:
# /tmp/ipykernel_230/1162773426.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   source_image=imageio.imread("/kaggle/input/deep-fake-data/RDJ.jpg")

# %%
#pip install imageio[ffmpeg]

# %%
#pip install imageio[pyav]

# %%
#resizing
source_image=resize(source_image,(256,256))[...,:3]
driver_video=[resize(frame ,(256,256))[...,:3] for frame in driver_video]

# %%
#mearge the image into video frame by frame
def display(source,driver,generated=None):
    fig=plt.figure(figsize=(8+4*(generated is not None),6))
    arr=[]
    for i in range(len(driver)):
        col=[source]
        col.append(driver[i])
        if generated is not None:
            col.append(generated[i])

        visual=plt.imshow(np.concatenate(col,axis=1),animated=True)
        plt.axis('off')
        arr.append([visual])

    anime=animation.ArtistAnimation(fig,arr,interval=50,repeat_delay=1000)
    plt.close()
    return anime

# %%
HTML(display(source_image,driver_video).to_html5_video())
# Out:
# <video width="800" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# !git clone https://github.com/AliaksandrSiarohin/first-order-model.git

# %%
cd first-order-model/

# %%
ls
# Out:
# Dockerfile       config/             frames_dataset.py  run.py
# LICENSE.md       crop-video.py       logger.py          sup-mat/
# README.md        data/               modules/           sync_batchnorm/
# __pycache__/     demo.ipynb          old_demo.ipynb     train.py
# animate.py       demo.py             reconstruction.py
# augmentation.py  demo_jupyter.ipynb  requirements.txt

# %%
from demo import load_checkpoints
generator, kp_detector = load_checkpoints(config_path='/kaggle/working/first-order-model/config/vox-256.yaml', checkpoint_path="/kaggle/input/damedane-vox-data/vox-adv-cpk.pth.tar")
# Out:
# /kaggle/working/first-order-model/demo.py:43: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path)

# %%
#pip install ffmpeg-python

# %%
from demo import make_animation
from skimage import img_as_ubyte

predictions = make_animation(source_image, driver_video, generator, kp_detector)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/parallel_apply.py:79: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.device(device), torch.cuda.stream(stream), autocast(enabled=autocast_enabled):
#   0%|          | 0/288 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:4373: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(

# %%
HTML(display(source_image,driver_video,predictions).to_html5_video())
# Out:
# <video width="1200" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
#saaving the video
#mageio.minsave('../new)video.mp4',[img_as_ubyte(i) for i in prediction])

# %%
predictions

# %%
#import pickle module
import pickle

# %%
#pickle the the model
pickle.dump(model)
#model.pkl

# %%
#unpickle the model
model=pickle.unpack(model.pkl)
